# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy

# %%
train_path = "../data/train.csv"
test_path = "../data/test.csv"

train_df = pd.read_csv(train_path)
test_df = pd.read_csv(test_path)

# %%
print("Train shape:", train_df.shape)
print("Test shape:", test_df.shape)
# Out:
# Train shape: (1460, 81)
# Test shape: (1459, 80)

# %%
train_df.head()
train_df.info()
train_df.describe()
train_df.isnull().sum().sort_values(ascending=False).head(20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
train_df["SalePrice"].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
train_df["SalePrice"].median()
# Out:
# np.float64(163000.0)

# %%
train_df["SalePrice"].mode()
# Out:
# 0    140000
# Name: SalePrice, dtype: int64

# %%
train_df["SalePrice"].var()
# Out:
# np.float64(6311111264.297448)

# %%
train_df['SalePrice'].skew()
# Out:
# np.float64(1.8828757597682129)

# %%
train_df['SalePrice'].kurt()
# Out:
# np.float64(6.536281860064529)

# %%
train_df['SalePrice'].hist(bins=30)
sns.histplot(train_df['SalePrice'], kde=True)
# Out:
# <Axes: xlabel='SalePrice', ylabel='Count'>

# %%
sns.boxplot(x=train_df['SalePrice'])
# Out:
# <Axes: xlabel='SalePrice'>

# %%
np.log1p(train_df['SalePrice']).skew()
# Out:
# np.float64(0.12134661989685333)

# %%
np.log(train_df['SalePrice']).skew()
# Out:
# np.float64(0.12133506220520406)

# %%
np.sqrt(train_df['SalePrice']).skew()
# Out:
# np.float64(0.9431527373310963)

# %%
np.log1p(train_df['SalePrice']).kurt()
# Out:
# np.float64(0.809519155707878)

# %%
np.log(train_df['SalePrice']).kurt()
# Out:
# np.float64(0.8095319958036296)

# %%
np.sqrt(train_df['SalePrice']).kurt()
# Out:
# np.float64(1.9578038790969754)

# %%
np.log1p(train_df['SalePrice']).hist(bins=30)
sns.histplot(np.log1p(train_df['SalePrice']), kde=True)
# Out:
# <Axes: xlabel='SalePrice', ylabel='Count'>

# %%
np.log(train_df['SalePrice']).hist(bins=30)
sns.histplot(np.log(train_df['SalePrice']), kde=True)
# Out:
# <Axes: xlabel='SalePrice', ylabel='Count'>

# %%
np.sqrt(train_df['SalePrice']).hist(bins=30)
sns.histplot(np.sqrt(train_df['SalePrice']), kde=True)
# Out:
# <Axes: xlabel='SalePrice', ylabel='Count'>

# %%
np.log1p(train_df['SalePrice']).hist(bins=30)
sns.boxplot(x=np.log1p(train_df['SalePrice']))
# Out:
# <Axes: xlabel='SalePrice'>

# %%
np.log(train_df['SalePrice']).hist(bins=30)
sns.boxplot(x=np.log(train_df['SalePrice']))
# Out:
# <Axes: xlabel='SalePrice'>

# %%
np.sqrt(train_df['SalePrice']).hist(bins=30)
sns.boxplot(x=np.sqrt(train_df['SalePrice']))
# Out:
# <Axes: xlabel='SalePrice'>

# %%
train_df['SalePrice'] = np.log1p(train_df['SalePrice'])

# %%
train_df['SalePrice'].hist(bins=30)
sns.histplot(train_df['SalePrice'], kde=True)
# Out:
# <Axes: xlabel='SalePrice', ylabel='Count'>

# %%
train_df['SalePrice'].hist(bins=30)
sns.violinplot(x=train_df['SalePrice'])
# Out:
# <Axes: xlabel='SalePrice'>
